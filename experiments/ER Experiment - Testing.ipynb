# %%
# Import Libraries
import matplotlib.pyplot as plt
import networkx as nx
import itertools
import numpy as np
import scipy as sp
from numpy.linalg import pinv
from numpy.random import randint, normal
from networkx.algorithms.clique import find_cliques, enumerate_all_cliques, make_max_clique_graph, graph_number_of_cliques
from networkx.algorithms.matching import maximal_matching
from networkx.algorithms.operators.unary import complement
from networkx.generators.random_graphs import erdos_renyi_graph #CHANGE THIS IMPORT TO INCLUDE OTHER GRAPH TYPES
from networkx.linalg.algebraicconnectivity import algebraic_connectivity
from scipy import stats
import itertools as it
from collections import Counter

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('modules'))
import block_RK as ac

# %%
# Adjust plot size
plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# # ER Experiments

# %% [markdown]
# ### graph set up

# %%
# Initialize Graph
n = 50
p = 0.6
G = erdos_renyi_graph(n, p)
m = len(G.edges())

# %%
# Initialize Incidence Matrix
A = nx.linalg.graphmatrix.incidence_matrix(G)
A = sp.sparse.csr_matrix.todense(A).transpose()
# their incidence matrix is binary, we need to convert one of the ones to a -1
for i in range(np.shape(A)[0]):
    negindex = np.where(A[i,:] == 1)
    A[i,negindex[1][0]] = -1

# %%
# Fix x, b
# Secret initial vector x
x = np.random.rand(n,1)
# Zero Vector b
b = np.zeros((m,1))
# Find mean of x
xbar = np.mean(x)
# Create solution vector (vector with just xbar as values)
sol = np.full((n,1), xbar)

# %% [markdown]
# ### n = 320, p = 1, Path gossip

# %%
# Path Gossip with l = 100
N = 50
l = 5
paths, test_x, x_list, errs = ac.blockRK_path(A, G, sol, b, N, x, l)
# Out:
# IntProgress(value=0, max=51)

# %%
ac.collapse_plt(x_list, n, N)
plt.show()
plt.savefig("plots/ER_test_path_collapse.svg", format='svg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-c501ad8f6ded> in <module>
#       1 ac.collapse_plt(x_list, n, N)
#       2 plt.show()
# ----> 3 plt.savefig("plots/ER_test_path_collapse.svg", format='svg')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_svg.py in print_svg(self, filename, *args, **kwargs)
#    1182
#    1183     def print_svg(self, filename, *args, **kwargs):
# -> 1184         with cbook.open_file_cm(filename, "w", encoding="utf-8") as fh:
#    1185
#    1186             filename = getattr(fh, 'name', '')
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plots/ER_test_path_collapse.svg'

# %%
ac.error_plt(errs, G, paths, sol, N, 'path')
plt.show()
plt.savefig("plots/ER_test_path_error.svg", format='svg')

# %% [markdown]
# ### n = 320, p = 1, IES gossip

# %%
N = 60
ies = ac.blocks_from_ies(G, A)
test_x, testlist, errors = ac.blockRK(A, sol, b, ies, N, x)

# %%
ac.collapse_plt(testlist, n, N)
plt.show()
plt.savefig("plots/ER_test_ies_collapse.svg", format='svg')

# %%
ac.error_plt(errors, G, ies, sol, N, rate='ies')
plt.show()
plt.savefig("plots/ER_test_ies_error.svg", format='svg')

# %% [markdown]
# ### n = 320, p = 1, clique gossip

# %%
# upper bound
N = 150
cliques = ac.clique_edge_cover(G, A)
test_x, test2, err2 = ac.blockRK(A, sol, b, cliques, N, x)

# %%
ac.collapse_plt(test2, n, N)
plt.show()
plt.savefig("plots/ER_test_clique_collapse.svg", format='svg')

# %%
bound, r, sq = ac.error_plt(err2, G, cliques, sol, N, rate='cliques')
plt.show()
plt.savefig("plots/ER_test_clique_error.svg", format='svg')

# %% [markdown]
# ### randomly selected blocks

# %%
blocks = ac.random_blocks(A, 5, 100) # parameters are: incidence matrix, size of blocks, number of blocks
test4, list4, err4 = ac.blockRK(A, sol, b, blocks, N, x)

# %%
ac.collapse_plt(list4, n, N)
plt.show()
plt.savefig("plots/ER_test_arbi_collapse.svg", format='svg')

# %%
bound, r, sq = ac.error_plt(err4, G, blocks, sol, N, rate='arbi')
plt.show()
plt.savefig("plots/ER_test_arbi_error.svg", format='svg')

# %%
# Out:
# [(0, 38), (38, 33), (33, 23), (23, 45), (45, 16)]
