# %%
# Import Libraries
import matplotlib.pyplot as plt
import networkx as nx
import itertools
import numpy as np
import scipy as sp
from numpy.linalg import pinv
from numpy.random import randint, normal
from networkx.algorithms.clique import find_cliques, enumerate_all_cliques, make_max_clique_graph, graph_number_of_cliques
from networkx.algorithms.matching import maximal_matching
from networkx.algorithms.operators.unary import complement
from networkx.generators.random_graphs import erdos_renyi_graph #CHANGE THIS IMPORT TO INCLUDE OTHER GRAPH TYPES
from networkx.linalg.algebraicconnectivity import algebraic_connectivity
from scipy import stats
import itertools as it
from collections import Counter

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../modules'))
import block_RK as ac

# %%
# Adjust plot size
plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# # ER Experiments

# %% [markdown]
# ### graph set up

# %%
# Initialize Graph
n = 200
p = 0.6
G = erdos_renyi_graph(n, p)
m = len(G.edges())

# %%
# Initialize Incidence Matrix
A = nx.linalg.graphmatrix.incidence_matrix(G)
A = sp.sparse.csr_matrix.todense(A).transpose()
# their incidence matrix is binary, we need to convert one of the ones to a -1
for i in range(np.shape(A)[0]):
    negindex = np.where(A[i,:] == 1)
    A[i,negindex[1][0]] = -1

# %%
# Fix x, b
# Secret initial vector x
x = np.random.rand(n,1)
# Zero Vector b
b = np.zeros((m,1))
# Find mean of x
xbar = np.mean(x)
# Create solution vector (vector with just xbar as values)
sol = np.full((n,1), xbar)

# %% [markdown]
# ### l = 5

# %%
N = 300
l = 5
paths0, test_x0, x_list0, errs0 = ac.blockRK_path(A, G, sol, b, N, x, l)
# Out:
# IntProgress(value=0, max=301)

# %%
ac.collapse_plt(x_list0, n, N)
plt.show()
plt.savefig("plots/ER_L5_path_collapse.svg", format='svg')

# %%
plt.semilogy(range(len(errs0)), errs0, 'b', linewidth=4, label = 'Block Gossip (Paths)')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig("plots/ER_L5_path_error.svg", format='svg')

# %% [markdown]
# ### l = 15

# %%
l = 15
paths, test_x, x_list, errs1 = ac.blockRK_path(A, G, sol, b, N, x, l)
# Out:
# IntProgress(value=0, max=301)

# %%
ac.collapse_plt(x_list, n, N)
plt.show()
plt.savefig("plots/ER_L15_path_collapse.svg", format='svg')

# %%
plt.semilogy(range(len(errs1)), errs1, 'b', linewidth=4, label = 'Block Gossip (Paths)')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig("plots/ER_L15_path_error.svg", format='svg')

# %% [markdown]
# ### l = 10

# %%
l = 10
paths2, x2, xlist2, errs2 = ac.blockRK_path(A, G, sol, b, N, x, l)
# Out:
# IntProgress(value=0, max=301)

# %%
ac.collapse_plt(xlist2, n, N)
plt.show()
plt.savefig("plots/ER_L10_path_collapse.svg", format='svg')

# %%
plt.semilogy(range(len(errs2)), errs2, 'b', linewidth=4, label = 'Block Gossip (Paths)')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig("plots/ER_L10_path_error.svg", format='svg')

# %% [markdown]
# ### l = 20

# %%
l = 20
paths3, x3, xlist3, errs3 = ac.blockRK_path(A, G, sol, b, N, x, l)
# Out:
# IntProgress(value=0, max=301)

# %%
ac.collapse_plt(xlist3, n, N)
plt.show()
plt.savefig("plots/ER_L20_path_collapse.svg", format='svg')

# %%
plt.semilogy(range(len(errs3)), errs3, 'b', linewidth=4, label = 'Block Gossip (Paths)')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig("plots/ER_L20_path_error.svg", format='svg')

# %% [markdown]
# ### path length vs convergence

# %%
plt.semilogy(range(np.shape(errs0)[0]), errs0, 'b', linewidth=4, label = r'l = 25')
plt.semilogy(range(np.shape(errs0)[0]), errs1, 'r', linewidth=4, label = r'l = 15')
plt.semilogy(range(np.shape(errs0)[0]), errs2, 'g', linewidth=4, label = r'l = 10')
plt.semilogy(range(np.shape(errs0)[0]), errs3, 'p', linewidth=4, label = r'l = 20')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
