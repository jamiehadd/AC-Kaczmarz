# %%
# Import Libraries
import matplotlib.pyplot as plt
import networkx as nx
import itertools
import numpy as np
import scipy as sp
from numpy.linalg import pinv
from numpy.random import randint, normal
from networkx.algorithms.clique import find_cliques, enumerate_all_cliques, make_max_clique_graph, graph_number_of_cliques
from networkx.algorithms.matching import maximal_matching
from networkx.algorithms.operators.unary import complement
from networkx.generators.random_graphs import erdos_renyi_graph #CHANGE THIS IMPORT TO INCLUDE OTHER GRAPH TYPES
from networkx.linalg.algebraicconnectivity import algebraic_connectivity
from scipy import stats
import itertools as it
from collections import Counter

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../modules'))
import block_RK as ac

# %%
# Adjust plot size
plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# # ER Experiments

# %% [markdown]
# ### graph set up

# %%
# Initialize Graph
n = 200
p = 0.6
G = erdos_renyi_graph(n, p)
m = len(G.edges())

# %%
# Initialize Incidence Matrix
A = nx.linalg.graphmatrix.incidence_matrix(G)
A = sp.sparse.csr_matrix.todense(A).transpose()
# their incidence matrix is binary, we need to convert one of the ones to a -1
for i in range(np.shape(A)[0]):
    negindex = np.where(A[i,:] == 1)
    A[i,negindex[1][0]] = -1

# %%
# Fix x, b
# Secret initial vector x
x = np.random.rand(n,1)
# Zero Vector b
b = np.zeros((m,1))
# Find mean of x
xbar = np.mean(x)
# Create solution vector (vector with just xbar as values)
sol = np.full((n,1), xbar)

# %% [markdown]
# ### l = 5

# %%
N = 75
l = 5
paths0, test_x0, x_list0, errs0 = ac.blockRK_path(A, G, sol, b, N, x, l)
# Out:
# IntProgress(value=0, max=76)

# %%
ac.collapse_plt(x_list0, n, N)
plt.show()
plt.savefig("plots/ER_L50_path_collapse.svg", format='svg')

# %%
bound5, r5, err5 = ac.error_plt(errs0, G, paths0, sol, N, 'path')
plt.show()
plt.savefig("plots/ER_L5_path_error.svg", format='svg')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-b764b4fb5802> in <module>
# ----> 1 bound25, r25, err25 = ac.error_plt(errs0, G, paths0, sol, N, 'path')
#       2 plt.show()
#       3 plt.savefig("plots/ER_L50_path_error.svg", format='svg')
#
# ~\Documents\ac\AC-Kaczmarz\experiments\modules\block_RK.py in error_plt(errors, G, blks, sol, N, rate)
#     213         label = 'Block Gossip (Independent Edge Sets)'
#     214     elif rate == 'path':
# --> 215         r = rate_paths(G, blks)
#     216         label = 'Block Gossip (Paths)'
#     217     elif rate == 'arbi':
#
# ~\Documents\ac\AC-Kaczmarz\experiments\modules\block_RK.py in rate_paths(G, blks)
#     166 def rate_paths(G, blks):
#     167     k = len(blks)
# --> 168     bound = 1-rR(blks)[0]*algebraic_connectivity(G)/(4*k)
#     169     return bound
#     170
#
# <decorator-gen-808> in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     403         new_args = list(args)
#     404         new_args[random_state_index] = random_state
# --> 405         return func(*new_args, **kwargs)
#     406     return _random_state
#     407
#
# <decorator-gen-807> in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      80             raise nx.NetworkXNotImplemented(msg)
#      81         else:
# ---> 82             return not_implement_for_func(*args, **kwargs)
#      83     return _not_implemented_for
#      84
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#     410     find_fiedler = _get_fiedler_func(method)
#     411     x = None if method != 'lobpcg' else _rcm_estimate(G, G)
# --> 412     sigma, fiedler = find_fiedler(L, x, normalized, tol, seed)
#     413     return sigma
#     414
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in find_fiedler(L, x, normalized, tol, seed)
#     298             q = 1 if method == 'tracemin_pcg' else min(4, L.shape[0] - 1)
#     299             X = asmatrix(seed.normal(size=(q, L.shape[0]))).T
# --> 300             sigma, X = _tracemin_fiedler(L, X, normalized, tol, method)
#     301             return sigma[0], X[:, 0]
#     302     elif method == 'lanczos' or method == 'lobpcg':
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in _tracemin_fiedler(L, X, normalized, tol, method)
#     282         # L \ X can have an arbitrary projection on the nullspace of L,
#     283         # which will be eliminated.
# --> 284         W[:, :] = solver.solve(X, tol)
#     285         X = (inv(W.T * X) * W.T).T  # Preserves Fortran storage order.
#     286         project(X)
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in solve(self, B, tol)
#      63         X = ndarray(B.shape, order='F')
#      64         for j in range(B.shape[1]):
# ---> 65             X[:, j] = self._solve(B[:, j], tol)
#      66         return X
#      67
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in _solve(self, b, tol)
#      78         # Iterate.
#      79         while True:
# ---> 80             Ap = A(p)
#      81             alpha = rz / ddot(p, Ap)
#      82             x = daxpy(p, x, a=alpha)
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in <lambda>(x)
#     244     if method == 'tracemin_pcg':
#     245         D = L.diagonal().astype(float)
# --> 246         solver = _PCGSolver(lambda x: L * x, lambda x: D * x)
#     247     elif method == 'tracemin_chol' or method == 'tracemin_lu':
#     248         # Convert A to CSC to suppress SparseEfficiencyWarning.
#
# ~\anaconda3\lib\site-packages\scipy\sparse\base.py in __mul__(self, other)
#     465             # Fast path for the most common case
#     466             if other.shape == (N,):
# --> 467                 return self._mul_vector(other)
#     468             elif other.shape == (N, 1):
#     469                 return self._mul_vector(other.ravel()).reshape(M, 1)
#
# ~\anaconda3\lib\site-packages\scipy\sparse\compressed.py in _mul_vector(self, other)
#     474         # csr_matvec or csc_matvec
#     475         fn = getattr(_sparsetools, self.format + '_matvec')
# --> 476         fn(M, N, self.indptr, self.indices, self.data, other, result)
#     477
#     478         return result
#
# KeyboardInterrupt:

# %% [markdown]
# ### l = 15

# %%
l = 15
paths, test_x, x_list, errs1 = ac.blockRK_path(A, G, sol, b, N, x, l)

# %%
ac.collapse_plt(x_list, n, N)
plt.show()
plt.savefig("plots/ER_L15_path_collapse.svg", format='svg')

# %%
bound15, r15, err15 = ac.error_plt(errs1, G, paths, sol, N, 'path')
plt.show()
plt.savefig("plots/ER_L15_path_error.svg", format='svg')

# %% [markdown]
# ### l = 10

# %%
l = 10
paths2, x2, xlist2, errs2 = ac.blockRK_path(A, G, sol, b, N, x, l)
# Out:
# IntProgress(value=0, max=76)

# %%
ac.collapse_plt(xlist2, n, N)
plt.show()
plt.savefig("plots/ER_L10_path_collapse.svg", format='svg')

# %%
bound10, r10, err10 = ac.error_plt(errs2, G, paths2, sol, N, 'path')
plt.show()
plt.savefig("plots/ER_L10_path_error.svg", format='svg')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7807bec2dc6e> in <module>
# ----> 1 bound10, r10, err10 = ac.error_plt(errs2, G, paths2, sol, N, 'path')
#       2 plt.show()
#       3 plt.savefig("plots/ER_L10_path_error.svg", format='svg')
#
# ~\Documents\ac\AC-Kaczmarz\experiments\modules\block_RK.py in error_plt(errors, G, blks, sol, N, rate)
#     213         label = 'Block Gossip (Independent Edge Sets)'
#     214     elif rate == 'path':
# --> 215         r = rate_paths(G, blks)
#     216         label = 'Block Gossip (Paths)'
#     217     elif rate == 'arbi':
#
# ~\Documents\ac\AC-Kaczmarz\experiments\modules\block_RK.py in rate_paths(G, blks)
#     166 def rate_paths(G, blks):
#     167     k = len(blks)
# --> 168     bound = 1-rR(blks)[0]*algebraic_connectivity(G)/(4*k)
#     169     return bound
#     170
#
# <decorator-gen-808> in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     403         new_args = list(args)
#     404         new_args[random_state_index] = random_state
# --> 405         return func(*new_args, **kwargs)
#     406     return _random_state
#     407
#
# <decorator-gen-807> in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      80             raise nx.NetworkXNotImplemented(msg)
#      81         else:
# ---> 82             return not_implement_for_func(*args, **kwargs)
#      83     return _not_implemented_for
#      84
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#     410     find_fiedler = _get_fiedler_func(method)
#     411     x = None if method != 'lobpcg' else _rcm_estimate(G, G)
# --> 412     sigma, fiedler = find_fiedler(L, x, normalized, tol, seed)
#     413     return sigma
#     414
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in find_fiedler(L, x, normalized, tol, seed)
#     298             q = 1 if method == 'tracemin_pcg' else min(4, L.shape[0] - 1)
#     299             X = asmatrix(seed.normal(size=(q, L.shape[0]))).T
# --> 300             sigma, X = _tracemin_fiedler(L, X, normalized, tol, method)
#     301             return sigma[0], X[:, 0]
#     302     elif method == 'lanczos' or method == 'lobpcg':
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in _tracemin_fiedler(L, X, normalized, tol, method)
#     282         # L \ X can have an arbitrary projection on the nullspace of L,
#     283         # which will be eliminated.
# --> 284         W[:, :] = solver.solve(X, tol)
#     285         X = (inv(W.T * X) * W.T).T  # Preserves Fortran storage order.
#     286         project(X)
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in solve(self, B, tol)
#      63         X = ndarray(B.shape, order='F')
#      64         for j in range(B.shape[1]):
# ---> 65             X[:, j] = self._solve(B[:, j], tol)
#      66         return X
#      67
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in _solve(self, b, tol)
#      78         # Iterate.
#      79         while True:
# ---> 80             Ap = A(p)
#      81             alpha = rz / ddot(p, Ap)
#      82             x = daxpy(p, x, a=alpha)
#
# ~\anaconda3\lib\site-packages\networkx\linalg\algebraicconnectivity.py in <lambda>(x)
#     244     if method == 'tracemin_pcg':
#     245         D = L.diagonal().astype(float)
# --> 246         solver = _PCGSolver(lambda x: L * x, lambda x: D * x)
#     247     elif method == 'tracemin_chol' or method == 'tracemin_lu':
#     248         # Convert A to CSC to suppress SparseEfficiencyWarning.
#
# ~\anaconda3\lib\site-packages\scipy\sparse\base.py in __mul__(self, other)
#     465             # Fast path for the most common case
#     466             if other.shape == (N,):
# --> 467                 return self._mul_vector(other)
#     468             elif other.shape == (N, 1):
#     469                 return self._mul_vector(other.ravel()).reshape(M, 1)
#
# ~\anaconda3\lib\site-packages\scipy\sparse\compressed.py in _mul_vector(self, other)
#     474         # csr_matvec or csc_matvec
#     475         fn = getattr(_sparsetools, self.format + '_matvec')
# --> 476         fn(M, N, self.indptr, self.indices, self.data, other, result)
#     477
#     478         return result
#
# KeyboardInterrupt:

# %% [markdown]
# ### l = 20

# %%
l = 20
paths3, x3, xlist3, errs3 = ac.blockRK_path(A, G, sol, b, N, x, l)

# %%
ac.collapse_plt(xlist3, n, N)
plt.show()
plt.savefig("plots/ER_L20_path_collapse.svg", format='svg')

# %%
bound20, r20, err20 = ac.error_plt(errs3, G, paths3, sol, N, 'path')
plt.show()
plt.savefig("plots/ER_L20_path_error.svg", format='svg')

# %% [markdown]
# ### path length vs constant

# %%
r_list = [(5, r5), (15, r15), (10, r10), (20, r20)]

# %%
plt.scatter(*zip(*r_list))
plt.legend(prop={'size': 15})
plt.xlabel('Path Length', fontsize=15)
plt.ylabel(r'Rate Constant', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
plt.savefig("plots/ER_path_rate.svg", format='svg')

# %% [markdown]
# ### path length vs convergence

# %%
plt.semilogy(range(np.shape(errors)[0]), errs0, 'b', linewidth=4, label = r'l = 25')
plt.semilogy(range(np.shape(errors)[0]), errs1, 'r', linewidth=4, label = r'l = 15')
plt.semilogy(range(np.shape(errors)[0]), errs2, 'g', linewidth=4, label = r'l = 10')
plt.semilogy(range(np.shape(errors)[0]), errs3, 'p', linewidth=4, label = r'l = 20')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
