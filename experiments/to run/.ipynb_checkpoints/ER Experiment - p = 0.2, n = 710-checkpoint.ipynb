# %%
# Import Libraries
import matplotlib.pyplot as plt
import networkx as nx
import itertools
import numpy as np
import scipy as sp
import pickle
from numpy.linalg import pinv
from numpy.random import randint, normal
from networkx.algorithms.clique import find_cliques, enumerate_all_cliques, make_max_clique_graph, graph_number_of_cliques
from networkx.algorithms.matching import maximal_matching
from networkx.algorithms.operators.unary import complement
from networkx.generators.random_graphs import erdos_renyi_graph #CHANGE THIS IMPORT TO INCLUDE OTHER GRAPH TYPES
from networkx.linalg.algebraicconnectivity import algebraic_connectivity
from scipy import stats
import itertools as it
from collections import Counter

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../modules'))
import block_RK as ac

# %%
# Adjust plot size
plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# # ER Experiments

# %% [markdown]
# ### experimental set-up

# %%
# Initialize Graph
n = 200
p = 0.2
G = erdos_renyi_graph(n, p)
m = len(G.edges())

# %%
# Initialize Incidence Matrix
A = nx.linalg.graphmatrix.incidence_matrix(G)
A = sp.sparse.csr_matrix.todense(A).transpose()
# their incidence matrix is binary, we need to convert one of the ones to a -1
for i in range(np.shape(A)[0]):
    negindex = np.where(A[i,:] == 1)
    A[i,negindex[1][0]] = -1

# %%
# Fix x, b
# Secret initial vector x
x = np.random.rand(n,1)
# Zero Vector b
b = np.zeros((m,1))
# Find mean of x
xbar = np.mean(x)
# Create solution vector (vector with just xbar as values)
sol = np.full((n,1), xbar)

# %% [markdown]
# ### Path gossip

# %%
# Path Gossip with l = 100
N = 200
l = 10
paths, testx, x_list, errs = ac.blockRK_path(A, G, sol, b, N, x, l)
with open("errors/path_p02.txt", "wb") as fp:
    pickle.dump(errs, fp)

# %%
ac.collapse_plt(x_list, n, N)
plt.show()
plt.savefig("plots/ER_p02_path_collapse.svg", format='svg')
np.savetxt("errors/path_p02.csv", errs, delimiter = ",")

# %%
plt.semilogy(range(len(errs)), errs, 'b', linewidth=4, label = 'Block Gossip (Paths)')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig("plots/ER_p02_path_error.svg", format='svg')

# %% [markdown]
# ### IES gossip

# %%
N = 200
ies = ac.blocks_from_ies(G, A)
test_x, xlist, errs1 = ac.blockRK(A, sol, b, ies, N, x)
with open("errors/ies_p02.txt", "wb") as fp:
    pickle.dump(errs1, fp)

# %%
ac.collapse_plt(xlist, n, N)
plt.show()
plt.savefig("plots/ER_p02_ies_collapse.svg", format='svg')

# %%
ac.error_plt(errs1, G, ies, sol, N, rate='ies')
plt.show()
plt.savefig("plots/ER_p02_ies_error.svg", format='svg')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-df884dcf7a3c> in <module>()
# ----> 1 ac.error_plt(errs1, G, ies, sol, N, rate='ies')
#       2 plt.show()
#       3 plt.savefig("plots/ER_p02_ies_error.svg", format='svg')
#
# /home/benjarman/AC-Kaczmarz/experiments/modules/block_RK.py in error_plt(errors, G, blks, sol, N, rate)
#     210         label = 'Block Gossip (Cliques)'
#     211     elif rate == 'ies':
# --> 212         r = rate_ies(G,blks)
#     213         label = 'Block Gossip (Independent Edge Sets)'
#     214     elif rate == 'path':
#
# /home/benjarman/AC-Kaczmarz/experiments/modules/block_RK.py in rate_ies(G, blks)
#     160 def rate_ies(G, blks):
#     161     k = len(blks)
# --> 162     bound = 1-rR(blks)[0]*algebraic_connectivity(G)/(2*k)
#     163     return bound
#     164
#
# <decorator-gen-836> in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     406         new_args = list(args)
#     407         new_args[random_state_index] = random_state
# --> 408         return func(*new_args, **kwargs)
#     409
#     410     return _random_state
#
# <decorator-gen-835> in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      76             raise nx.NetworkXNotImplemented(msg)
#      77         else:
# ---> 78             return not_implement_for_func(*args, **kwargs)
#      79
#      80     return _not_implemented_for
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#     423     find_fiedler = _get_fiedler_func(method)
#     424     x = None if method != "lobpcg" else _rcm_estimate(G, G)
# --> 425     sigma, fiedler = find_fiedler(L, x, normalized, tol, seed)
#     426     return sigma
#     427
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in find_fiedler(L, x, normalized, tol, seed)
#     307             q = 1 if method == "tracemin_pcg" else min(4, L.shape[0] - 1)
#     308             X = asarray(seed.normal(size=(q, L.shape[0]))).T
# --> 309             sigma, X = _tracemin_fiedler(L, X, normalized, tol, method)
#     310             return sigma[0], X[:, 0]
#     311
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in _tracemin_fiedler(L, X, normalized, tol, method)
#     290         # L \ X can have an arbitrary projection on the nullspace of L,
#     291         # which will be eliminated.
# --> 292         W[:, :] = solver.solve(X, tol)
#     293         X = (inv(W.T @ X) @ W.T).T  # Preserves Fortran storage order.
#     294         project(X)
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in solve(self, B, tol)
#      57         X = ndarray(B.shape, order="F")
#      58         for j in range(B.shape[1]):
# ---> 59             X[:, j] = self._solve(B[:, j], tol)
#      60         return X
#      61
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in _solve(self, b, tol)
#      72         # Iterate.
#      73         while True:
# ---> 74             Ap = A(p)
#      75             alpha = rz / ddot(p, Ap)
#      76             x = daxpy(p, x, a=alpha)
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in <lambda>(x)
#     252     if method == "tracemin_pcg":
#     253         D = L.diagonal().astype(float)
# --> 254         solver = _PCGSolver(lambda x: L * x, lambda x: D * x)
#     255     elif method == "tracemin_chol" or method == "tracemin_lu":
#     256         # Convert A to CSC to suppress SparseEfficiencyWarning.
#
# /usr/lib/python3/dist-packages/scipy/sparse/base.py in __mul__(self, other)
#     354             # Fast path for the most common case
#     355             if other.shape == (N,):
# --> 356                 return self._mul_vector(other)
#     357             elif other.shape == (N, 1):
#     358                 return self._mul_vector(other.ravel()).reshape(M, 1)
#
# /usr/lib/python3/dist-packages/scipy/sparse/compressed.py in _mul_vector(self, other)
#     496         # csr_matvec or csc_matvec
#     497         fn = getattr(_sparsetools,self.format + '_matvec')
# --> 498         fn(M, N, self.indptr, self.indices, self.data, other, result)
#     499
#     500         return result
#
# KeyboardInterrupt:

# %% [markdown]
# ### clique gossip

# %%
# upper bound
N = 1000
cliques = ac.clique_edge_cover(G, A)
test_x, xlist, errs2 = ac.blockRK(A, sol, b, cliques, N, x)
with open("errors/clique_p02.txt", "wb") as fp:
    pickle.dump(errs2, fp)

# %%
ac.collapse_plt(xlist, n, N)
plt.show()
plt.savefig("plots/ER_p02_clique_collapse.svg", format='svg')

# %%
ac.error_plt(errs2, G, cliques, sol, N,  rate='cliques')
plt.show()
plt.savefig("plots/ER_p02_clique_error.svg", format='svg')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-80ed33bbc981> in <module>()
# ----> 1 ac.error_plt(errs2, G, cliques, sol, N,  rate='cliques')
#       2 plt.show()
#       3 plt.savefig("plots/ER_p02_clique_error.svg", format='svg')
#
# /home/benjarman/AC-Kaczmarz/experiments/modules/block_RK.py in error_plt(errors, G, blks, sol, N, rate)
#     207 def error_plt(errors, G, blks, sol, N, rate='arbi'):
#     208     if rate == 'cliques':
# --> 209         r = rate_cliques(G, blks)
#     210         label = 'Block Gossip (Cliques)'
#     211     elif rate == 'ies':
#
# /home/benjarman/AC-Kaczmarz/experiments/modules/block_RK.py in rate_cliques(G, blks)
#     172 def rate_cliques(G, blks):
#     173     k = len(blks)
# --> 174     bound = 1-rR(blks)[0]*algebraic_connectivity(G)/(4*k)
#     175     return bound
#     176
#
# <decorator-gen-836> in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     406         new_args = list(args)
#     407         new_args[random_state_index] = random_state
# --> 408         return func(*new_args, **kwargs)
#     409
#     410     return _random_state
#
# <decorator-gen-835> in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      76             raise nx.NetworkXNotImplemented(msg)
#      77         else:
# ---> 78             return not_implement_for_func(*args, **kwargs)
#      79
#      80     return _not_implemented_for
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in algebraic_connectivity(G, weight, normalized, tol, method, seed)
#     423     find_fiedler = _get_fiedler_func(method)
#     424     x = None if method != "lobpcg" else _rcm_estimate(G, G)
# --> 425     sigma, fiedler = find_fiedler(L, x, normalized, tol, seed)
#     426     return sigma
#     427
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in find_fiedler(L, x, normalized, tol, seed)
#     307             q = 1 if method == "tracemin_pcg" else min(4, L.shape[0] - 1)
#     308             X = asarray(seed.normal(size=(q, L.shape[0]))).T
# --> 309             sigma, X = _tracemin_fiedler(L, X, normalized, tol, method)
#     310             return sigma[0], X[:, 0]
#     311
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in _tracemin_fiedler(L, X, normalized, tol, method)
#     290         # L \ X can have an arbitrary projection on the nullspace of L,
#     291         # which will be eliminated.
# --> 292         W[:, :] = solver.solve(X, tol)
#     293         X = (inv(W.T @ X) @ W.T).T  # Preserves Fortran storage order.
#     294         project(X)
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in solve(self, B, tol)
#      57         X = ndarray(B.shape, order="F")
#      58         for j in range(B.shape[1]):
# ---> 59             X[:, j] = self._solve(B[:, j], tol)
#      60         return X
#      61
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in _solve(self, b, tol)
#      72         # Iterate.
#      73         while True:
# ---> 74             Ap = A(p)
#      75             alpha = rz / ddot(p, Ap)
#      76             x = daxpy(p, x, a=alpha)
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/linalg/algebraicconnectivity.py in <lambda>(x)
#     252     if method == "tracemin_pcg":
#     253         D = L.diagonal().astype(float)
# --> 254         solver = _PCGSolver(lambda x: L * x, lambda x: D * x)
#     255     elif method == "tracemin_chol" or method == "tracemin_lu":
#     256         # Convert A to CSC to suppress SparseEfficiencyWarning.
#
# /usr/lib/python3/dist-packages/scipy/sparse/base.py in __mul__(self, other)
#     354             # Fast path for the most common case
#     355             if other.shape == (N,):
# --> 356                 return self._mul_vector(other)
#     357             elif other.shape == (N, 1):
#     358                 return self._mul_vector(other.ravel()).reshape(M, 1)
#
# /usr/lib/python3/dist-packages/scipy/sparse/compressed.py in _mul_vector(self, other)
#     496         # csr_matvec or csc_matvec
#     497         fn = getattr(_sparsetools,self.format + '_matvec')
# --> 498         fn(M, N, self.indptr, self.indices, self.data, other, result)
#     499
#     500         return result
#
# KeyboardInterrupt:

# %% [markdown]
# ### randomly selected blocks

# %%
N = 200
s = 20
bn = 50
blocks = ac.random_blocks(A, s, bn) # parameters are: incidence matrix, size of blocks, number of blocks
test4, list4, errs3 = ac.blockRK(A, sol, b, blocks, N, x)
with open("errors/ran_p02.txt", "wb") as fp:
    pickle.dump(errs3, fp)

# %%
ac.collapse_plt(list4, n, N)
plt.show()
plt.savefig("plots/ER_p02_arbi_collapse.svg", format='svg')

# %%
bound, r, sq = ac.error_plt(errs3, G, blocks, sol, N, rate='arbi')
plt.show()
plt.savefig("plots/ER_p02_arbi_error.svg", format='svg')

# %%
plt.semilogy(range(200), errs[:200], 'b', linewidth=4, label = r'Path Gossip')
plt.semilogy(range(200), errs1[:200], 'r', linewidth=4, label = r'IES Gossip')
plt.semilogy(range(200), errs2[:200], 'g', linewidth=4, label = r'Clique Gossip')
plt.semilogy(range(200), errs3[:200], 'p', linewidth=4, label = r'Random Gossip')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
plt.savefig("plots/ER_p02_comparison.svg", format='svg')
