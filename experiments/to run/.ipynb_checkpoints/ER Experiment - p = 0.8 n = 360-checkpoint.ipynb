# %%
# Import Libraries
import matplotlib.pyplot as plt
import networkx as nx
import itertools
import numpy as np
import scipy as sp
import pickle
from numpy.linalg import pinv
from numpy.random import randint, normal
from networkx.algorithms.clique import find_cliques, enumerate_all_cliques, make_max_clique_graph, graph_number_of_cliques
from networkx.algorithms.matching import maximal_matching
from networkx.algorithms.operators.unary import complement
from networkx.generators.random_graphs import erdos_renyi_graph #CHANGE THIS IMPORT TO INCLUDE OTHER GRAPH TYPES
from networkx.linalg.algebraicconnectivity import algebraic_connectivity
from scipy import stats
import itertools as it
from collections import Counter

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../modules'))
import block_RK as ac

# %%
# Adjust plot size
plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# # ER Experiments

# %% [markdown]
# ### experimental set-up

# %%
# Initialize Graph
n = 200
p = 0.8
G = erdos_renyi_graph(n, p)
m = len(G.edges())

# %%
# Initialize Incidence Matrix
A = nx.linalg.graphmatrix.incidence_matrix(G)
A = sp.sparse.csr_matrix.todense(A).transpose()
# their incidence matrix is binary, we need to convert one of the ones to a -1
for i in range(np.shape(A)[0]):
    negindex = np.where(A[i,:] == 1)
    A[i,negindex[1][0]] = -1

# %%
# Fix x, b
# Secret initial vector x
x = np.random.rand(n,1)
# Zero Vector b
b = np.zeros((m,1))
# Find mean of x
xbar = np.mean(x)
# Create solution vector (vector with just xbar as values)
sol = np.full((n,1), xbar)

# %% [markdown]
# ### Path gossip

# %%
# Path Gossip with l = 100
N = 300
l = 10
paths, testx, x_list, errs = ac.blockRK_path(A, G, sol, b, N, x, l)
with open("errors/path_p08.txt", "wb") as fp:
    pickle.dump(errs, fp)

# %%
ac.collapse_plt(x_list, n, N)
plt.show()
plt.savefig("plots/ER_p08_path_collapse.svg", format='svg')

# %%
plt.semilogy(range(len(errs)), errs, 'b', linewidth=4, label = 'Block Gossip (Paths)')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig("plots/ER_p08_path_error.svg", format='svg')

# %% [markdown]
# ### IES gossip

# %%
N = 200
ies = ac.blocks_from_ies(G, A)
test_x, xlist, errs2 = ac.blockRK(A, sol, b, ies, N, x)
with open("errors/ies_p08.txt", "wb") as fp:
    pickle.dump(errs2, fp)

# %%
ac.collapse_plt(xlist, n, N)
plt.show()
plt.savefig("plots/ER_p08_ies_collapse.svg", format='svg')

# %%
ac.error_plt(errs2, G, ies, sol, N, rate='ies')
plt.show()
plt.savefig("plots/ER_p08_ies_error.svg", format='svg')

# %% [markdown]
# ### clique gossip

# %%
N = 1000
bound = 10
cliques = ac.clique_edge_cover(G, A, bound = bound)
test_x, xlist, errs3 = ac.blockRK(A, sol, b, cliques, N, x)
with open("errors/clique_p08.txt", "wb") as fp:
    pickle.dump(errs3, fp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-9374d2960094> in <module>()
#       1 N = 1000
#       2 bound = 10
# ----> 3 cliques = ac.clique_edge_cover(G, A, bound = bound)
#       4 test_x, xlist, errs3 = ac.blockRK(A, sol, b, cliques, N, x)
#       5 with open("errors/clique_p08.txt", "wb") as fp:
#
# /home/benjarman/AC-Kaczmarz/experiments/modules/block_RK.py in clique_edge_cover(G, A, bound)
#     322     display(f)
#     323     while len(H.edges)>0:
# --> 324         foo = largest_clique_bounded(list(find_cliques(H)), bound)
#     325         foo = edges_from_pnts(foo)
#     326         H.remove_edges_from(foo)
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/algorithms/clique.py in find_cliques(G)
#     200                         subg = subg_q
#     201                         cand = cand_q
# --> 202                         u = max(subg, key=lambda u: len(cand & adj[u]))
#     203                         ext_u = cand - adj[u]
#     204             else:
#
# /home/benjarman/.local/lib/python3.6/site-packages/networkx/algorithms/clique.py in <lambda>(u)
#     200                         subg = subg_q
#     201                         cand = cand_q
# --> 202                         u = max(subg, key=lambda u: len(cand & adj[u]))
#     203                         ext_u = cand - adj[u]
#     204             else:
#
# KeyboardInterrupt:

# %%
ac.collapse_plt(xlist, n, N)
plt.show()
plt.savefig("plots/ER_p08_cliques_collapse.svg", format='svg')

# %%
ac.error_plt(errs3, G, cliques, sol, N, rate='cliques')
plt.show()
plt.savefig("plots/ER_p08_ies_error.svg", format='svg')

# %% [markdown]
# ### random

# %%
N = 200
s = 20
bn = 50
blocks = ac.random_blocks(A, s, bn) # parameters are: incidence matrix, size of blocks, number of blocks
test4, list4, err4 = ac.blockRK(A, sol, b, blocks, N, x)
with open("errors/ran_p08.txt", "wb") as fp:
    pickle.dump(err4, fp)

# %%
ac.collapse_plt(list4, n, N)
plt.show()
plt.savefig("plots/ER_p08_arbi_collapse.svg", format='svg')

# %%
bound, r, sq = ac.error_plt(err4, G, blocks, sol, N, rate='arbi')
plt.show()
plt.savefig("plots/ER_p08_arbi_error.svg", format='svg')

# %%
plt.semilogy(range(200), errs[:200], 'b', linewidth=4, label = r'Path Gossip')
plt.semilogy(range(200), errs2[:200], 'r', linewidth=4, label = r'IES Gossip')
plt.semilogy(range(200), err4[:200], 'p', linewidth=4, label = r'Random Gossip')
plt.legend(prop={'size': 15})
plt.xlabel('Iteration number, $k$', fontsize=15)
plt.ylabel(r'$||c_k-c*||^2$', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
plt.savefig("plots/ER_p08_comparison.svg", format='svg')
